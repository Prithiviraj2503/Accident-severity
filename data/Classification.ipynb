# %%
# Importing the required packages 
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier 
import sklearn.metrics as metrics

# %%
#load data
data=pd.read_csv("trainingdata.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3057 entries, 0 to 3056
# Data columns (total 11 columns):
# Unnamed: 0             3057 non-null int64
# Number of Vehicles     3057 non-null int64
# 1st Road Class         3057 non-null int64
# Road Surface           3057 non-null int64
# Lighting Conditions    3057 non-null int64
# Weather Conditions     3057 non-null int64
# Casualty Class         3057 non-null int64
# Casualty Severity      3057 non-null int64
# Sex of Casualty        3057 non-null int64
# Age of Casualty        3057 non-null int64
# Type of Vehicle        3057 non-null int64
# dtypes: int64(11)
# memory usage: 262.8 KB

# %%
#feature and target split
feat = ['Number of Vehicles','1st Road Class','Road Surface','Lighting Conditions','Weather Conditions','Casualty Class','Sex of Casualty','Age of Casualty','Type of Vehicle']
features=data[feat]
target=data['Casualty Severity']

# %%
#Split training data(70%) and testing data (30%)
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=1)

# %%
print("DECISION TREE LEARNING")
#Building decision tree model
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
#Predict the response for test dataset
y_pred = clf.predict(X_test)

#Perormance evaluation of Decision tree
import matplotlib.pyplot as plt

print("Confusion Matrix", metrics.confusion_matrix(y_test, y_pred))
print("Accuracy of the model is", metrics.accuracy_score(y_test, y_pred))
print("precision of the model is", metrics.precision_score(y_test, y_pred))
print("Recall of the model is", metrics.recall_score(y_test, y_pred))
print("ROC Curve")
tpr, fpr, thres=metrics.roc_curve(y_test, y_pred)

plt.plot(tpr, fpr)
plt.title("ROC curve")
plt.xlabel("True Positive Rate")
plt.ylabel("False Positive Rate")
plt.show()
# Out:
# DECISION TREE LEARNING
# Confusion Matrix [[758  71]
#  [ 66  23]]
# Accuracy of the model is 0.8507625272331155
# precision of the model is 0.24468085106382978
# Recall of the model is 0.25842696629213485
# ROC Curve

# %%
print("SUPPORT VECTOR MACHINE LEARNING")
#prediction using SVM
from sklearn import svm

svmcl = svm.SVC(kernel='linear') # Linear Kernel
#Train the model using the training sets
svmcl.fit(X_train, y_train)
#Predict the response for test dataset
y_pred_SVM = svmcl.predict(X_test)


print("Confusion Matrix", metrics.confusion_matrix(y_test, y_pred_SVM))
print("Accuracy of the model is", metrics.accuracy_score(y_test, y_pred_SVM))
print("precision of the model is", metrics.precision_score(y_test, y_pred_SVM))
print("Recall of the model is", metrics.recall_score(y_test, y_pred_SVM))
print("ROC Curve")
tpr, fpr, thres=metrics.roc_curve(y_test, y_pred_SVM)

plt.plot(tpr, fpr)
plt.title("ROC curve")
plt.xlabel("True Positive Rate")
plt.ylabel("False Positive Rate")
plt.show()
# Out:
# SUPPORT VECTOR MACHINE LEARNING
# Confusion Matrix [[829   0]
#  [ 89   0]]
# Accuracy of the model is 0.9030501089324618
# precision of the model is 0.0
# Recall of the model is 0.0
# ROC Curve
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("NAIVE BAYES LEARNING")

from sklearn.naive_bayes import GaussianNB

#Create a Gaussian Classifier
gnb = GaussianNB()
#Train the model using the training sets
gnb.fit(X_train, y_train)
#Predict the response for test dataset
y_pred_nb=gnb.predict(X_test)

print("Confusion Matrix", metrics.confusion_matrix(y_test, y_pred_nb))
print("Accuracy of the model is", metrics.accuracy_score(y_test, y_pred_nb))
print("precision of the model is", metrics.precision_score(y_test, y_pred_nb))
print("Recall of the model is", metrics.recall_score(y_test, y_pred_nb))
print("ROC Curve")
tpr, fpr, thres=metrics.roc_curve(y_test, y_pred_nb)

plt.plot(tpr, fpr)
plt.title("ROC curve")
plt.xlabel("True Positive Rate")
plt.ylabel("False Positive Rate")
plt.show()
# Out:
# NAIVE BAYES LEARNING
# Confusion Matrix [[822   7]
#  [ 87   2]]
# Accuracy of the model is 0.8976034858387799
# precision of the model is 0.2222222222222222
# Recall of the model is 0.02247191011235955
# ROC Curve

# %%
print("K-NEAREST NEIGHBOUR LEARNING")
from sklearn.neighbors import KNeighborsClassifier 

knn = KNeighborsClassifier(n_neighbors=7) 
knn.fit(X_train, y_train)
y_pred_knn=knn.predict(X_test)

print("Confusion Matrix", metrics.confusion_matrix(y_test, y_pred_knn))
print("Accuracy of the model is", metrics.accuracy_score(y_test, y_pred_knn))
print("precision of the model is", metrics.precision_score(y_test, y_pred_knn))
print("Recall of the model is", metrics.recall_score(y_test, y_pred_knn))
print("ROC Curve")
tpr, fpr, thres=metrics.roc_curve(y_test, y_pred_knn)

plt.plot(tpr, fpr)
plt.title("ROC curve")
plt.xlabel("True Positive Rate")
plt.ylabel("False Positive Rate")
plt.show()
# Out:
# K-NEAREST NEIGHBOUR LEARNING
# Confusion Matrix [[823   6]
#  [ 88   1]]
# Accuracy of the model is 0.8976034858387799
# precision of the model is 0.14285714285714285
# Recall of the model is 0.011235955056179775
# ROC Curve

# %%
from sklearn.ensemble import GradientBoostingClassifier
print("Gradient Boosting Classifier")

gb = GradientBoostingClassifier(learning_rate=0.1)
gb.fit(X_train, y_train)
y_pred_gb=gb.predict(X_test)

print("Confusion Matrix", metrics.confusion_matrix(y_test, y_pred_gb))
print("Accuracy of the model is", metrics.accuracy_score(y_test, y_pred_gb))
print("precision of the model is", metrics.precision_score(y_test, y_pred_gb))
print("Recall of the model is", metrics.recall_score(y_test, y_pred_gb))
print("ROC Curve")
tpr, fpr, thres=metrics.roc_curve(y_test, y_pred_gb)

plt.plot(tpr, fpr)
plt.title("ROC curve")
plt.xlabel("True Positive Rate")
plt.ylabel("False Positive Rate")
plt.show()
# Out:
# Gradient Boosting Classifier
# Confusion Matrix [[819  10]
#  [ 83   6]]
# Accuracy of the model is 0.8986928104575164
# precision of the model is 0.375
# Recall of the model is 0.06741573033707865
# ROC Curve

# %%
import pickle

#dump on picle
pickle.dump(gb, open('model.pkl','wb'))
